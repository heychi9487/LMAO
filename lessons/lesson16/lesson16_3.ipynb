# %%
import numpy as np
students=np.random.randint(50,101,size=(50,5))
display(students.ndim)
display(students.size)
display(students.shape)
print(students[:,0].sum())
print(students[0].sum())
print(students[0].mean())
print(students[0].max())
print(students[0].min())
print(students[0].std())
# Out:
# array([[ 59,  95,  77,  90,  63],
#        [ 73,  88,  55,  78,  52],
#        [ 79,  80, 100,  61,  71],
#        [ 58,  86,  55,  52,  81],
#        [ 87,  76,  71,  55,  62],
#        [ 84,  77,  67,  54,  59],
#        [ 50,  62,  73,  64,  83],
#        [ 81,  60,  76,  81,  98],
#        [ 58,  95,  68,  83,  71],
#        [ 64,  75,  58,  59,  53],
#        [ 93,  62,  69,  66,  97],
#        [ 72,  97,  93,  82,  76],
#        [ 85,  85,  76,  79,  60],
#        [ 91,  75,  77,  70,  57],
#        [ 53,  86,  56,  76,  90],
#        [ 63,  67,  84,  97,  90],
#        [ 84,  74,  93,  74,  88],
#        [ 67,  78,  73,  90,  79],
#        [ 77,  63,  73,  54,  67],
#        [ 73,  64,  99,  92,  75],
#        [ 66,  50,  55,  56,  91],
#        [ 54,  71,  55,  54,  81],
#        [ 63,  83,  51,  63,  78],
#        [ 83, 100,  76,  80,  58],
#        [ 51,  53,  95,  72,  69],
#        [100,  58,  98,  96,  68],
#        [ 55,  82,  52,  83,  96],
#        [ 64,  70,  80,  96,  50],
#        [ 68,  55,  50,  57,  64],
#        [ 61,  50,  71,  73,  84],
#        [ 88,  95,  97,  58,  86],
#        [ 90,  69,  67,  78,  52],
#        [ 93,  79,  70,  61,  86],
#        [ 65,  69,  52,  93,  77],
#        [ 58,  56,  51,  87,  88],
#        [ 64,  98,  76,  55, 100],
#        [ 73,  67,  89,  95,  77],
#        [ 82,  85,  82,  56,  66],
#        [ 65,  96,  65,  80,  98],
#        [ 76,  97,  91,  80,  63],
#        [ 52,  52,  60,  90,  70],
#        [ 72,  95,  85,  79,  76],
#        [ 77,  55,  96,  97,  75],
#        [ 65,  58,  57,  79,  60],
#        [ 76,  92,  64,  62,  64],
#        [ 87,  68,  69,  76,  92],
#        [ 91,  91,  60,  75,  77],
#        [ 93,  58,  52,  88,  71],
#        [ 55,  90,  96,  69,  81],
#        [ 70,  69,  50,  74,  57]], dtype=int32)

# %%
np.mean(students,axis=1)
# Out:
# array([76.8, 69.2, 78.2, 66.4, 70.2, 68.2, 66.4, 79.2, 75. , 61.8, 77.4,
#        84. , 77. , 74. , 72.2, 80.2, 82.6, 77.4, 66.8, 80.6, 63.6, 63. ,
#        67.6, 79.4, 68. , 84. , 73.6, 72. , 58.8, 67.8, 84.8, 71.2, 77.8,
#        71.2, 68. , 78.6, 80.2, 74.2, 80.8, 81.4, 64.8, 81.4, 80. , 63.8,
#        71.6, 78.4, 78.8, 72.4, 78.2, 64. ])
