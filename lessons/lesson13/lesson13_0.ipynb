# %%
import requests
from requests import Response
from pprint import pprint

youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
response:Response = requests.get(youbike_url)

# %%
data:list[dict] = response.json()
    
district:str = input("請輸入新北市行政區: ")
district += "區"

district_stations = []
for station in data:
    if station['sarea'] == district:
        district_stations.append(station)


if district_stations:
    pprint(district_stations)
else:
    print(f"沒有找到 {district} 行政區的站點資訊。請再輸入一次")
# Out:
# 沒有找到 a區 行政區的站點資訊。請再輸入一次

# %%
from requests import TooManyRedirects, HTTPError, Timeout
youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
response:Response=requests.get(youbike_url)

# %%
import requests
from requests import Response
from pprint import pprint
from requests import ConnectionError,TooManyRedirects,Timeout,HTTPError

youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
try:
    response:Response = requests.get(youbike_url)
    response.raise_for_status()
except ConnectionError:
    print("連線主機出問題")
except TooManyRedirects:
    print("太多轉址")
except Timeout:
    print("主機正在忙")
except HTTPError:
    print("status_不是200")
except:
    print("不明錯誤")
else:
    print("連線正常")
# Out:
# 連線主機出問題

# %%
import requests
from requests import Response
from pprint import pprint
from requests import ConnectionError,TooManyRedirects,Timeout,HTTPError

def connect_youbike() -> Response | str:    #回傳字串 or Response
    youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
    try:
        response:Response = requests.get(youbike_url)
        response.raise_for_status()
    except ConnectionError:
        return "連線主機出問題"
    except TooManyRedirects:
        return "太多轉址"
    except Timeout:
        return "主機正在忙"
    except HTTPError:
        return "status_不是200"
    except:
        return "不明錯誤"
    else:
        return response
def search_area(response:Response,district:str)-> list[dict]:
    data:list[dict] = response.json()
    district_stations = [station for station in data if station['sarea'] == district]
    return district_stations  

def main():
        response:Response | str = connect_youbike() 
        if not isinstance(response,Response):
            print(response)
            return
        
        district:str = input("請輸入新北市行政區: ")
        district += "區"        
        district_stations = search_area(response,district)
        if district_stations:
            pprint(district_stations)
        else:
            print(f"沒有找到 {district} 行政區的站點資訊。請再輸入一次")
            

if __name__ == '__main__':
    main()
# Out:
# 沒有找到 媽的區 行政區的站點資訊。請再輸入一次

# %%
data:list[dict] = response.json()
sareas:list[str] = []
for site in data:
    sareas.append(site['sarea'])
sareas
# Out:
# ['八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '八里區',
#  '三芝區',
#  '三芝區',
#  '三芝區',
#  '三芝區',
#  '三芝區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三重區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '三峽區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '土城區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '中和區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '五股區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '永和區',
#  '石門區',
#  '石門區',
#  '石碇區',
#  '石碇區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '汐止區',
#  '金山區',
#  '金山區',
#  '金山區',
#  '金山區',
#  '金山區',
#  '金山區',
#  '金山區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '林口區',
#  '坪林區',
#  '坪林區',
#  '坪林區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '板橋區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '泰山區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '淡水區',
#  '深坑區',
#  '深坑區',
#  '深坑區',
#  '深坑區',
#  '深坑區',
#  '深坑區',
#  '萬里區',
#  '萬里區',
#  '萬里區',
#  '萬里區',
#  '瑞芳區',
#  '瑞芳區',
#  '瑞芳區',
#  '瑞芳區',
#  '瑞芳區',
#  '瑞芳區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區',
#  '新店區']

# %%
data:list[dict] = response.json()
sareas:set = set()
for site in data:
    sareas.add(site['sarea'])
list(sareas)
# Out:
# ['金山區',
#  '泰山區',
#  '土城區',
#  '永和區',
#  '深坑區',
#  '三芝區',
#  '瑞芳區',
#  '三重區',
#  '八里區',
#  '萬里區',
#  '石門區',
#  '石碇區',
#  '林口區',
#  '板橋區',
#  '中和區',
#  '汐止區',
#  '淡水區',
#  '坪林區',
#  '五股區',
#  '三峽區',
#  '新店區']
