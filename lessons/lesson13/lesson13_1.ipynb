# %%
import requests
from requests import Response
from pprint import pprint
from requests import ConnectionError,TooManyRedirects,Timeout,HTTPError

def connect_youbike() -> Response | str:    #讓"connect_youbike()" return str 或 class Response
    youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
    try:
        response:Response = requests.get(youbike_url)
        response.raise_for_status()
    except ConnectionError:
        return "連線主機出問題"   #如果有出問題讓"connect_youbike()" return str
    except TooManyRedirects:
        return "太多轉址"
    except Timeout:
        return "主機正在忙"   
    except HTTPError:
        return "status_不是200"
    except:
        return "不明錯誤"
    else:
        return response   #如果沒出問題讓"connect_youbike()" return response, which is class Response

def main():
        response:Response | str = connect_youbike() 
        if not isinstance(response,Response):   #判斷如果response不是Response就會return
            print(response)
            return
    
        print("連線成功")
        data:list[dict] = response.json()    
        district:str = input("請輸入新北市行政區: ")
        district += "區"
        district_stations = []
        for station in data:
            if station['sarea'] == district:
                district_stations.append(station)


        if district_stations:
            pprint(district_stations)
        else:
            print(f"沒有找到 {district} 行政區的站點資訊。請再輸入一次")





if __name__ == '__main__':
    main()
# Out:
# 連線成功
# 沒有找到 m/3區 行政區的站點資訊。請再輸入一次

# %%
import requests
from requests import Response
from pprint import pprint
from requests import ConnectionError,TooManyRedirects,Timeout,HTTPError
import pyinputplus as pyip

def connect_youbike() -> Response | str:
    youbike_url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?size=1000'
    try:
        response:Response = requests.get(youbike_url)
        response.raise_for_status()
    except ConnectionError:
        return "連線主機出問題"
    except TooManyRedirects:
        return "太多轉址"
    except Timeout:
        return "主機正在忙"
    except HTTPError:
        return "status_不是200"
    except:
        return "不明錯誤"
    else:
        return response
def search_area(response:Response,district:str)-> list[dict]:
    data:list[dict] = response.json()
    district_stations = [station for station in data if station['sarea'] == district]
    return district_stations  

def get_areas(response:Response) -> list[str]:
    data:list[dict] = response.json()
    sareas:set = set()
    for site in data:
        sareas.add(site['sarea'])
    return list(sareas)

def main():
        response:Response | str = connect_youbike() 
        if not isinstance(response,Response):
            print(response)
            return
        
        areas = get_areas(response)
        district:str = pyip.inputMenu(areas,"請輸入新北市行政區:\n",numbered=True)        
        district_stations = search_area(response,district)
        if district_stations:
            pprint(district_stations)
        else:
            print(f"沒有找到 {district} 行政區的站點資訊。請再輸入一次")
            

if __name__ == '__main__':
    main()
# Out:
# 請輸入新北市行政區:
# 1. 八里區
# 2. 汐止區
# 3. 板橋區
# 4. 深坑區
# 5. 三重區
# 6. 永和區
# 7. 淡水區
# 8. 中和區
# 9. 金山區
# 10. 林口區
# 11. 石碇區
# 12. 五股區
# 13. 萬里區
# 14. 瑞芳區
# 15. 新店區
# 16. 三峽區
# 17. 三芝區
# 18. 泰山區
# 19. 土城區
# 20. 坪林區
# 21. 石門區
# [{'act': '1',
#   'ar': '東勢街15-1號西南側',
#   'aren': 'No. 15-1, Dongshi St. (Southwest)',
#   'bemp': '26',
#   'lat': '25.03881',
#   'lng': '121.62429',
#   'mday': '20240729151822',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_東勢宜興活動中心',
#   'snaen': 'YouBike2.0_Yixing Dongshi Activity Center',
#   'sno': '500214001',
#   'tot': '33'},
#  {'act': '1',
#   'ar': '工建路50號南側',
#   'aren': 'No. 50, Gongjian Rd. (South)',
#   'bemp': '20',
#   'lat': '25.06319',
#   'lng': '121.64112',
#   'mday': '20240729160721',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '24',
#   'sna': 'YouBike2.0_工建樟樹一路口',
#   'snaen': 'YouBike2.0_Gongjian Rd. & Zhangshu 1st Rd. Intersection',
#   'sno': '500214002',
#   'tot': '44'},
#  {'act': '1',
#   'ar': '樟樹二路137號東側',
#   'aren': 'No. 137, Zhangshu 2nd Rd. (East)',
#   'bemp': '46',
#   'lat': '25.06693',
#   'lng': '121.64039',
#   'mday': '20240729160821',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_樟樹國小',
#   'snaen': 'YouBike2.0_Zhangshu Elementary School',
#   'sno': '500214003',
#   'tot': '50'},
#  {'act': '1',
#   'ar': '大同路一段237號',
#   'aren': 'No. 237, Sec. 1, Datong Rd.',
#   'bemp': '14',
#   'lat': '25.05793',
#   'lng': '121.63496',
#   'mday': '20240729160319',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '40',
#   'sna': 'YouBike2.0_台灣科學園區',
#   'snaen': 'YouBike2.0_Taiwan Science Park',
#   'sno': '500214004',
#   'tot': '54'},
#  {'act': '1',
#   'ar': '南陽街209號',
#   'aren': 'No. 209, Nanyang St.',
#   'bemp': '17',
#   'lat': '25.05808',
#   'lng': '121.62602',
#   'mday': '20240729154820',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '16',
#   'sna': 'YouBike2.0_雍和科學園區',
#   'snaen': 'YouBike2.0_Yonghe Science Park',
#   'sno': '500214005',
#   'tot': '33'},
#  {'act': '1',
#   'ar': '大同路二段182號東側',
#   'aren': 'No.182, Sec. 2, Datong Rd.',
#   'bemp': '19',
#   'lat': '25.06274482486429',
#   'lng': '121.64684226184235',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '58',
#   'sna': 'YouBike2.0_汐科火車站(南)',
#   'snaen': 'YouBike2.0_Xike Railway Station(South)',
#   'sno': '500214006',
#   'tot': '77'},
#  {'act': '1',
#   'ar': '中興路150巷12號西南側',
#   'aren': 'No.12, Ln. 150, Zhongxing Rd.',
#   'bemp': '23',
#   'lat': '25.06507',
#   'lng': '121.63304',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '26',
#   'sna': 'YouBike2.0_原興廣場',
#   'snaen': 'YouBike2.0_Yuan Xing Square',
#   'sno': '500214007',
#   'tot': '49'},
#  {'act': '1',
#   'ar': '新台五路一段114號',
#   'aren': 'No.114, Sec. 1, Xintai 5th Rd.',
#   'bemp': '20',
#   'lat': '25.06126',
#   'lng': '121.64951',
#   'mday': '20240729155920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '43',
#   'sna': 'YouBike2.0_東方科學園區',
#   'snaen': 'YouBike2.0_Oriental Science Park',
#   'sno': '500214008',
#   'tot': '63'},
#  {'act': '1',
#   'ar': '大同路二段197號南側',
#   'aren': 'No.197,Sec. 2, Datong Rd.',
#   'bemp': '25',
#   'lat': '25.06426',
#   'lng': '121.65294',
#   'mday': '20240729160537',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '51',
#   'sna': 'YouBike2.0_汐科火車站(北)',
#   'snaen': 'YouBike2.0_Xike Railway Station(North)',
#   'sno': '500214009',
#   'tot': '76'},
#  {'act': '1',
#   'ar': '莊敬街84-1號南側',
#   'aren': 'No.84-1, Zhuangjing St.',
#   'bemp': '54',
#   'lat': '25.06103',
#   'lng': '121.65559',
#   'mday': '20240729160420',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_青山國民中小學',
#   'snaen': 'YouBike2.0_Qingshan Elementary and Junior High School',
#   'sno': '500214010',
#   'tot': '56'},
#  {'act': '1',
#   'ar': '民權街二段90號',
#   'aren': 'No.90, Sec. 2, Minquan St.',
#   'bemp': '43',
#   'lat': '25.04758',
#   'lng': '121.61889',
#   'mday': '20240729153314',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_白雲國小',
#   'snaen': 'YouBike2.0_Jinlong Elementary School',
#   'sno': '500214011',
#   'tot': '43'},
#  {'act': '1',
#   'ar': '水源路二段42號',
#   'aren': 'No.42 to No.68, Sec. 2, Shuiyuan Rd.',
#   'bemp': '76',
#   'lat': '25.05688',
#   'lng': '121.65521',
#   'mday': '20240729160715',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_文化白雲公園',
#   'snaen': 'YouBike2.0_Wenhua-Baiyun Park',
#   'sno': '500214012',
#   'tot': '76'},
#  {'act': '1',
#   'ar': '連興路/龍安路28巷',
#   'aren': 'lianxing',
#   'bemp': '60',
#   'lat': '25.06299',
#   'lng': '121.65443',
#   'mday': '20240729160821',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_連興龍安路口',
#   'snaen': 'YouBike2.0_lianxing',
#   'sno': '500214013',
#   'tot': '70'},
#  {'act': '1',
#   'ar': '南興路62號旁(南興公園內)',
#   'aren': 'No.62, Nanxing Rd.',
#   'bemp': '25',
#   'lat': '25.05978',
#   'lng': '121.65255',
#   'mday': '20240729160821',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_南興公園',
#   'snaen': 'YouBike2.0_Nanxing Park',
#   'sno': '500214014',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '明峰街13號(右側路側)',
#   'aren': 'No.13, Mingfeng St., Xizhi Dist.',
#   'bemp': '16',
#   'lat': '25.07105',
#   'lng': '121.63502',
#   'mday': '20240729153621',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_民族二街明峰街口',
#   'snaen': 'YouBike2.0_Minzu 2nd & Mingfeng Intersection',
#   'sno': '500214015',
#   'tot': '22'},
#  {'act': '1',
#   'ar': '福德一路86巷23號(旁)',
#   'aren': 'No. 86, Fude 1st Rd., Xizhi Dist.',
#   'bemp': '24',
#   'lat': '25.06894',
#   'lng': '121.63748',
#   'mday': '20240729160721',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_康福公園',
#   'snaen': 'YouBike2.0_Kangfu Park',
#   'sno': '500214016',
#   'tot': '28'},
#  {'act': '1',
#   'ar': '南昌街/新昌路口(西側廣場)',
#   'aren': 'Nanchang St./Xinchang Rd.',
#   'bemp': '23',
#   'lat': '25.06891',
#   'lng': '121.66275',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '33',
#   'sna': 'YouBike2.0_汐止火車站',
#   'snaen': 'YouBike2.0_Xizhi Railway Station',
#   'sno': '500214017',
#   'tot': '56'},
#  {'act': '1',
#   'ar': '忠孝東路484號至488號前',
#   'aren': 'No.484 to No.488, Zhongxiao E. Rd.',
#   'bemp': '26',
#   'lat': '25.07368',
#   'lng': '121.66626',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_橋東里(忠孝東路)',
#   'snaen': 'YouBike2.0_Qiaodong Village (Zhongxiao E. Rd.)',
#   'sno': '500214018',
#   'tot': '36'},
#  {'act': '1',
#   'ar': '茄苳路84號(崇德橋東里民活動中心前)',
#   'aren': 'No.84, Jiadong Rd.',
#   'bemp': '37',
#   'lat': '25.07051',
#   'lng': '121.667',
#   'mday': '20240729151314',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_崇德橋東活動中心',
#   'snaen': 'YouBike2.0_Chungde-Ciaodong Activity Center',
#   'sno': '500214019',
#   'tot': '37'},
#  {'act': '1',
#   'ar': '長江路101號(對面)',
#   'aren': 'No.101, Changjiang St., Xizhi Dist.',
#   'bemp': '20',
#   'lat': '25.07289',
#   'lng': '121.65865',
#   'mday': '20240729151025',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_世貿國家公園社區',
#   'snaen': 'YouBike2.0_Shi Mao National Park Community',
#   'sno': '500214020',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '汐萬路一段201號前',
#   'aren': 'No.201, Sec. 1, Xiwan Rd., Xizhi Dist.',
#   'bemp': '30',
#   'lat': '25.07207',
#   'lng': '121.65207',
#   'mday': '20240729160414',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_蘭庭序大廈',
#   'snaen': 'YouBike2.0_Lantingji Xu Community',
#   'sno': '500214021',
#   'tot': '30'},
#  {'act': '1',
#   'ar': '建成路78號南側',
#   'aren': 'No78, Jiancheng Rd',
#   'bemp': '43',
#   'lat': '25.07315',
#   'lng': '121.66256',
#   'mday': '20240729160721',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_國泰綜合醫院',
#   'snaen': 'YouBike2.0_Cathay General Hospital',
#   'sno': '500214022',
#   'tot': '44'},
#  {'act': '1',
#   'ar': '汐萬路二段279號',
#   'aren': 'No.279, Sec. 2, Xiwan Rd.',
#   'bemp': '8',
#   'lat': '25.08903',
#   'lng': '121.64595',
#   'mday': '20240729152522',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '12',
#   'sna': 'YouBike2.0_北港國小',
#   'snaen': 'YouBike2.0_Beigang Elementary School',
#   'sno': '500214023',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '明峰街281號東側',
#   'aren': 'No. 281, Mingfeng St., Xizhi Dist.(East)',
#   'bemp': '22',
#   'lat': '25.06809',
#   'lng': '121.62697',
#   'mday': '20240729160721',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_康寧街307巷',
#   'snaen': 'YouBike2.0_Ln. 307, Kangning St.',
#   'sno': '500214024',
#   'tot': '28'},
#  {'act': '1',
#   'ar': '忠三街8號',
#   'aren': 'No.8, Zhong 3rd St.',
#   'bemp': '29',
#   'lat': '25.0782',
#   'lng': '121.62449',
#   'mday': '20240729154421',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_忠山市民活動中心',
#   'snaen': 'YouBike2.0_Jhongshan Civil Activity Center',
#   'sno': '500214025',
#   'tot': '38'},
#  {'act': '0',
#   'ar': '大同路二段447號東側',
#   'aren': 'No.451, Sec. 2, Datong Rd.',
#   'bemp': '10',
#   'lat': '25.06781',
#   'lng': '121.65964',
#   'mday': '20240726031918',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_汐止公園',
#   'snaen': 'YouBike2.0_Xizhi Park',
#   'sno': '500214026',
#   'tot': '10'},
#  {'act': '1',
#   'ar': '忠孝東路211巷28號',
#   'aren': 'No. 1, Xinyi Rd., Xizhi Dist.',
#   'bemp': '17',
#   'lat': '25.06795',
#   'lng': '121.66168',
#   'mday': '20240729160919',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '63',
#   'sna': 'YouBike2.0_汐止火車站停車場',
#   'snaen': 'YouBike2.0_Xizhi Railway Station Parking Lot',
#   'sno': '500214027',
#   'tot': '99'},
#  {'act': '1',
#   'ar': '茄苳路158號',
#   'aren': 'No.158, Jiadong Rd., Xizhi Dist.',
#   'bemp': '42',
#   'lat': '25.06938',
#   'lng': '121.66979',
#   'mday': '20240729155620',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_崇德國小',
#   'snaen': 'YouBike2.0_Chongde Elementary School',
#   'sno': '500214028',
#   'tot': '47'},
#  {'act': '1',
#   'ar': '保一街79號西南側',
#   'aren': 'No. 70, Bao1. St.(Southwest)',
#   'bemp': '63',
#   'lat': '25.07952',
#   'lng': '121.67434',
#   'mday': '20240729154219',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '3',
#   'sna': 'YouBike2.0_保長公園',
#   'snaen': 'YouBike2.0_Baochang Park',
#   'sno': '500214029',
#   'tot': '66'},
#  {'act': '1',
#   'ar': '吉祥街8號南側',
#   'aren': 'No. 8, Jixiang St., Xizhi Dist.(South)',
#   'bemp': '29',
#   'lat': '25.08033',
#   'lng': '121.66846',
#   'mday': '20240729160522',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '14',
#   'sna': 'YouBike2.0_長安橋(吉祥街12巷)',
#   'snaen': 'YouBike2.0_Chang An Bridge (Ln. 12, Jixiang St.)',
#   'sno': '500214030',
#   'tot': '43'},
#  {'act': '1',
#   'ar': '中興路282號西側',
#   'aren': 'No.282, Zhongxing Rd. (West)',
#   'bemp': '21',
#   'lat': '25.06943',
#   'lng': '121.6284',
#   'mday': '20240729153421',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_金龍國小',
#   'snaen': 'YouBike2.0_Jinlong Elementary School',
#   'sno': '500214031',
#   'tot': '30'},
#  {'act': '1',
#   'ar': '忠孝東路9號東北側',
#   'aren': 'No.9, Zhongxiao E. Rd.(Northeast)',
#   'bemp': '25',
#   'lat': '25.06624',
#   'lng': '121.65907',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_汐止區綜合運動場',
#   'snaen': 'YouBike2.0_Xizhi Sports Field',
#   'sno': '500214032',
#   'tot': '34'},
#  {'act': '1',
#   'ar': '康寧街469巷19號東側',
#   'aren': 'No.19, Ln.469, Kangning St.(East)',
#   'bemp': '28',
#   'lat': '25.06947',
#   'lng': '121.63153',
#   'mday': '20240729154820',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '14',
#   'sna': 'YouBike2.0_金龍公園',
#   'snaen': 'YouBike2.0_Jinlong Park',
#   'sno': '500214033',
#   'tot': '42'},
#  {'act': '1',
#   'ar': '長安路17號(鄉長路一段)',
#   'aren': "No.17, Chang'an Rd.(Sec. 1, Xiangzhang Rd.)",
#   'bemp': '23',
#   'lat': '25.07823',
#   'lng': '121.66764',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '43',
#   'sna': 'YouBike2.0_五堵火車站',
#   'snaen': 'YouBike2.0_Wudu Railway Station',
#   'sno': '500214034',
#   'tot': '66'},
#  {'act': '1',
#   'ar': '新台五路一段262號',
#   'aren': 'No.262, Sec. 1, Xintaiwu Rd.',
#   'bemp': '23',
#   'lat': '25.06416',
#   'lng': '121.6583',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_汐止區公所',
#   'snaen': 'YouBike2.0_Xizhi Dist. Office',
#   'sno': '500214035',
#   'tot': '32'},
#  {'act': '1',
#   'ar': '仁愛路163號',
#   'aren': 'No.163, Ren’ai Rd., Xizhi Dist.',
#   'bemp': '57',
#   'lat': '25.0652',
#   'lng': '121.6641',
#   'mday': '20240729160320',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_仁愛路151巷口',
#   'snaen': 'YouBike2.0_Ren Ai Rd 151 Ln',
#   'sno': '500214036',
#   'tot': '59'},
#  {'act': '1',
#   'ar': '福德一路205號(對面)',
#   'aren': 'No. 205, Fude 1st Rd. (Opposite)',
#   'bemp': '36',
#   'lat': '25.06575',
#   'lng': '121.6351',
#   'mday': '20240729155221',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_福德一路201巷口(福德ONE社區)',
#   'snaen': 'YouBike2.0_Ln. 201, Fude 1st Rd.',
#   'sno': '500214037',
#   'tot': '37'},
#  {'act': '1',
#   'ar': '中興路45-1號(旁)',
#   'aren': 'No. 45-1, Zhongxing Rd.',
#   'bemp': '14',
#   'lat': '25.06227',
#   'lng': '121.63447',
#   'mday': '20240729150619',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '34',
#   'sna': 'YouBike2.0_矽谷園區',
#   'snaen': 'YouBike2.0_Silicon Valley Park',
#   'sno': '500214038',
#   'tot': '48'},
#  {'act': '1',
#   'ar': '康寧街61巷口(堤防邊)',
#   'aren': 'Ln. 61, Kangning St.',
#   'bemp': '21',
#   'lat': '25.06833',
#   'lng': '121.61988',
#   'mday': '20240729160620',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '9',
#   'sna': 'YouBike2.0_華城橋（康寧街61巷）',
#   'snaen': 'YouBike2.0_Huacheng Bridge (Ln. 61, Kangning St.)',
#   'sno': '500214039',
#   'tot': '30'},
#  {'act': '1',
#   'ar': '康寧街749號南側',
#   'aren': 'No. 749, Kangning St.(South)',
#   'bemp': '7',
#   'lat': '25.07299',
#   'lng': '121.6384',
#   'mday': '20240729150119',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_伯爵山莊第二期(康寧街)',
#   'snaen': "YouBike2.0_Earl's Villa Phase II (Corning Street)",
#   'sno': '500214040',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '招商街/啟德橋(東南側)',
#   'aren': 'Zhaoshang St. & Qide Bridge(Southeast)',
#   'bemp': '14',
#   'lat': '25.06786',
#   'lng': '121.66801',
#   'mday': '20240729155620',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_啟德橋(招商街)',
#   'snaen': 'YouBike2.0_Qide Bridge',
#   'sno': '500214041',
#   'tot': '19'},
#  {'act': '1',
#   'ar': '翠峰街2巷2號西南側',
#   'aren': 'No. 2, Ln. 2, Cuifeng St.(Southwest)',
#   'bemp': '7',
#   'lat': '25.07578',
#   'lng': '121.64481',
#   'mday': '20240729152221',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_樟江大橋',
#   'snaen': 'YouBike2.0_Zhangjiang Bridge',
#   'sno': '500214042',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '忠孝東路202號北側',
#   'aren': 'No. 202, Zhongxiao E. Rd.(North)',
#   'bemp': '6',
#   'lat': '25.06635',
#   'lng': '121.66172',
#   'mday': '20240729160721',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_秀峰高中(忠孝東路)',
#   'snaen': 'YouBike2.0_Xiufeng High School(Zhongxiao E. Rd.)',
#   'sno': '500214043',
#   'tot': '16'},
#  {'act': '1',
#   'ar': '和平街46巷26號北側',
#   'aren': 'No. 26, Ln. 46, Heping St.(North)',
#   'bemp': '7',
#   'lat': '25.07201',
#   'lng': '121.66270',
#   'mday': '20240729160619',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_台練橋',
#   'snaen': 'YouBike2.0_Tailian Bridge',
#   'sno': '500214044',
#   'tot': '14'},
#  {'act': '1',
#   'ar': '樟樹二路330巷32號東側',
#   'aren': 'No. 32, Ln. 330, Zhangshu 2nd Rd.(East)',
#   'bemp': '14',
#   'lat': '25.070296258183784',
#   'lng': '121.64286319301775',
#   'mday': '20240729160516',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_樟樹一山光路口',
#   'snaen': 'YouBike2.0_Zhangshu 1st. & Shanguang Rd. Intersection',
#   'sno': '500214045',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '汐科路321號',
#   'aren': 'No. 321, Xike Rd.',
#   'bemp': '6',
#   'lat': '25.06538',
#   'lng': '121.65693',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_汐止國民運動中心',
#   'snaen': 'YouBike2.0_Xizhi Civil Sports Center',
#   'sno': '500214046',
#   'tot': '12'},
#  {'act': '1',
#   'ar': '中興路177號',
#   'aren': 'No. 177, Zhongxing Rd.',
#   'bemp': '10',
#   'lat': '25.06641',
#   'lng': '121.63077',
#   'mday': '20240729160532',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_中興福德三路口',
#   'snaen': 'YouBike2.0_Zhongxing Fude 3rd Rd. Intersection',
#   'sno': '500214048',
#   'tot': '10'},
#  {'act': '1',
#   'ar': '建成路142巷5號東側',
#   'aren': 'No. 5, Ln. 142, Jiancheng Rd.(East)',
#   'bemp': '47',
#   'lat': '25.07335',
#   'lng': '121.66255',
#   'mday': '20240729155122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_建成路142巷口',
#   'snaen': 'YouBike2.0_Ln. 142, Jiancheng Rd. Intersection',
#   'sno': '500214049',
#   'tot': '53'},
#  {'act': '1',
#   'ar': '福德二路21號北側',
#   'aren': 'No. 21, Fude 2nd Rd.(North)',
#   'bemp': '11',
#   'lat': '25.06841',
#   'lng': '121.63533',
#   'mday': '20240729125914',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_福德二路19巷口',
#   'snaen': 'YouBike2.0_Ln. 19, Fude 2nd Rd. Intersection',
#   'sno': '500214050',
#   'tot': '12'},
#  {'act': '1',
#   'ar': '中興路60號西側',
#   'aren': 'No. 60, Zhongxing Rd.(West)',
#   'bemp': '12',
#   'lat': '25.06128',
#   'lng': '121.63535',
#   'mday': '20240729160122',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '8',
#   'sna': 'YouBike2.0_中興工建路口',
#   'snaen': 'YouBike2.0_Zhongxing Gongjian Rd. Intersection',
#   'sno': '500214051',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '長興街二段2巷1號北側',
#   'aren': 'No. 1, Ln. 2, Sec. 2, Changxing St.(North)',
#   'bemp': '13',
#   'lat': '25.08055',
#   'lng': '121.67187',
#   'mday': '20240729160620',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_長興橋',
#   'snaen': 'YouBike2.0_Changxing Bridge',
#   'sno': '500214052',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '長安路40號',
#   'aren': "No. 40 Chang'an Rd.",
#   'bemp': '0',
#   'lat': '25.07813',
#   'lng': '121.66821',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '13',
#   'sna': 'YouBike2.0_五堵車站(長安路)',
#   'snaen': "YouBike2.0_Wudu Sta.(Chang'an Rd.)",
#   'sno': '500214053',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '忠孝東路455號(西側高架橋下)',
#   'aren': 'No. 455, Zhongxiao E. Rd., Xizhi Dist.(Under the viaduct)',
#   'bemp': '29',
#   'lat': '25.07258',
#   'lng': '121.66558',
#   'mday': '20240729155320',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_大同建成路口',
#   'snaen': 'YouBike2.0_DatongJiancheng Rd. Intersection',
#   'sno': '500214054',
#   'tot': '30'},
#  {'act': '1',
#   'ar': '茄苳路296號',
#   'aren': 'No. 296, Jiadong Rd.',
#   'bemp': '14',
#   'lat': '25.06723',
#   'lng': '121.673',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_茄苳茄福街口',
#   'snaen': 'YouBike2.0_Jiadong Jiafu St. Intersection',
#   'sno': '500214055',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '長江街238-2號',
#   'aren': 'No. 238-2, Changjiang St.',
#   'bemp': '5',
#   'lat': '25.0794',
#   'lng': '121.6625',
#   'mday': '20240729131521',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '6',
#   'sna': 'YouBike2.0_春之霖社區',
#   'snaen': 'YouBike2.0_Chunzhilin Community',
#   'sno': '500214056',
#   'tot': '11'},
#  {'act': '1',
#   'ar': '鄉長路一段45號東北側',
#   'aren': 'No. 45, Sec. 1, Xiangzhang Rd.',
#   'bemp': '11',
#   'lat': '25.07553',
#   'lng': '121.66558',
#   'mday': '20240729153522',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '5',
#   'sna': 'YouBike2.0_五堵橋下籃球場',
#   'snaen': 'YouBike2.0_Wudu bridge Basketball court',
#   'sno': '500214057',
#   'tot': '17'},
#  {'act': '1',
#   'ar': '大同路二段713號東北側',
#   'aren': 'No. 713, Sec. 2, Datong Rd. (northeast)',
#   'bemp': '14',
#   'lat': '25.07336',
#   'lng': '121.66542',
#   'mday': '20240728215621',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_建成段平面停車場',
#   'snaen': 'YouBike2.0_Jianchengduan Parking Lot',
#   'sno': '500214058',
#   'tot': '15'},
#  {'act': '1',
#   'ar': '忠孝東路9號',
#   'aren': 'No. 9, Zhongxiao Rd.',
#   'bemp': '10',
#   'lat': '25.06416',
#   'lng': '121.65726',
#   'mday': '20240729160920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_汐止國民運動中心游泳池(忠孝東路)',
#   'snaen': 'YouBike2.0_Xizhi Civil Activity Center Swimming Pool (Zhongxiao E. '
#            'Rd.)',
#   'sno': '500214059',
#   'tot': '12'},
#  {'act': '1',
#   'ar': '樟樹一路258號西側',
#   'aren': 'No. 258, Zhangshu Rd. (West)',
#   'bemp': '18',
#   'lat': '25.06735',
#   'lng': '121.64240',
#   'mday': '20240729155220',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_樟樹國小(樟樹一路145巷口)',
#   'snaen': 'YouBike2.0_Zhangshu Elementary School (Ln.145, Zhangshu 1st Rd.)',
#   'sno': '500214060',
#   'tot': '20'},
#  {'act': '1',
#   'ar': '仁愛路106巷32號西側',
#   'aren': "No.32, Ln.106, Ren'ai Rd (West)",
#   'bemp': '14',
#   'lat': '25.06266',
#   'lng': '121.66294',
#   'mday': '20240729155920',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '2',
#   'sna': 'YouBike2.0_秀峰國小(仁愛路106巷)',
#   'snaen': "YouBike2.0_Xiufeng Elementary School (Ln. 106, Ren'ai Rd.)",
#   'sno': '500214062',
#   'tot': '16'},
#  {'act': '1',
#   'ar': '汐萬路三段246號',
#   'aren': 'No. 246, Sec. 3, Xiwan Rd.',
#   'bemp': '12',
#   'lat': '25.09705',
#   'lng': '121.64241',
#   'mday': '20240729151030',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '4',
#   'sna': 'YouBike2.0_汐止區農會附設老人活動中心',
#   'snaen': 'YouBike2.0_The Elderly Activity Center attached to Xizhi District '
#            'Farmers Association',
#   'sno': '500214063',
#   'tot': '16'},
#  {'act': '1',
#   'ar': '長興街二段62號(前)',
#   'aren': 'No. 62, Sec. 2, Changxing St. (Front)',
#   'bemp': '12',
#   'lat': '25.08192',
#   'lng': '121.67449',
#   'mday': '20240729151314',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '1',
#   'sna': 'YouBike2.0_長興街二段62號',
#   'snaen': 'YouBike2.0_No. 62, Sec. 2, Changxing St.',
#   'sno': '500214064',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '公園路10號(對面)',
#   'aren': 'No. 10, Gongyuan Rd. (Opposite)',
#   'bemp': '17',
#   'lat': '25.06813',
#   'lng': '121.65901',
#   'mday': '20240729155620',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '11',
#   'sna': 'YouBike2.0_水返腳公園',
#   'snaen': 'YouBike2.0_Shuifanjiao Park',
#   'sno': '500214065',
#   'tot': '28'},
#  {'act': '1',
#   'ar': '大同路三段148號(前)',
#   'aren': 'No. 148, Sec. 3, Datong Rd. (Front)',
#   'bemp': '6',
#   'lat': '25.07617',
#   'lng': '121.67296',
#   'mday': '20240729160522',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '13',
#   'sna': 'YouBike2.0_大同路三段148號',
#   'snaen': 'YouBike2.0_No. 148, Sec. 3, Datong Rd.',
#   'sno': '500214066',
#   'tot': '19'},
#  {'act': '1',
#   'ar': '汐萬路二段97-1號',
#   'aren': 'No. 97-1, Sec. 2, Xiwan Rd.',
#   'bemp': '2',
#   'lat': '25.08270',
#   'lng': '121.64843',
#   'mday': '20240729143521',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '7',
#   'sna': 'YouBike2.0_汐萬抽水站',
#   'snaen': 'YouBike2.0_Xiwan Pumping Station',
#   'sno': '500214067',
#   'tot': '9'},
#  {'act': '1',
#   'ar': '汐萬路一段312號(對面)',
#   'aren': 'No. 312, Sec. 1, Xiwan Rd. (Opposite)',
#   'bemp': '13',
#   'lat': '25.07479',
#   'lng': '121.65023',
#   'mday': '20240729153815',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '0',
#   'sna': 'YouBike2.0_汐萬康寧街口',
#   'snaen': 'YouBike2.0_Xiwan Rd. & Kangning St. Intersection',
#   'sno': '500214068',
#   'tot': '13'},
#  {'act': '1',
#   'ar': '同興路/大同路一段(西側)',
#   'aren': 'TongXing Rd. & Sec. 1, DaTong Rd. (West)',
#   'bemp': '20',
#   'lat': '25.05981',
#   'lng': '121.63882',
#   'mday': '20240729160522',
#   'sarea': '汐止區',
#   'sareaen': 'Xizhi Dist',
#   'sbi': '10',
#   'sna': 'YouBike2.0_同興大同路口',
#   'snaen': 'YouBike2.0_TongXing Rd. & DaTong Rd. Intersection',
#   'sno': '500214069',
#   'tot': '30'}]
