# %%
import numpy as np
np.linspace(1,50,num=100)
# Out:
# array([ 1.        ,  1.49494949,  1.98989899,  2.48484848,  2.97979798,
#         3.47474747,  3.96969697,  4.46464646,  4.95959596,  5.45454545,
#         5.94949495,  6.44444444,  6.93939394,  7.43434343,  7.92929293,
#         8.42424242,  8.91919192,  9.41414141,  9.90909091, 10.4040404 ,
#        10.8989899 , 11.39393939, 11.88888889, 12.38383838, 12.87878788,
#        13.37373737, 13.86868687, 14.36363636, 14.85858586, 15.35353535,
#        15.84848485, 16.34343434, 16.83838384, 17.33333333, 17.82828283,
#        18.32323232, 18.81818182, 19.31313131, 19.80808081, 20.3030303 ,
#        20.7979798 , 21.29292929, 21.78787879, 22.28282828, 22.77777778,
#        23.27272727, 23.76767677, 24.26262626, 24.75757576, 25.25252525,
#        25.74747475, 26.24242424, 26.73737374, 27.23232323, 27.72727273,
#        28.22222222, 28.71717172, 29.21212121, 29.70707071, 30.2020202 ,
#        30.6969697 , 31.19191919, 31.68686869, 32.18181818, 32.67676768,
#        33.17171717, 33.66666667, 34.16161616, 34.65656566, 35.15151515,
#        35.64646465, 36.14141414, 36.63636364, 37.13131313, 37.62626263,
#        38.12121212, 38.61616162, 39.11111111, 39.60606061, 40.1010101 ,
#        40.5959596 , 41.09090909, 41.58585859, 42.08080808, 42.57575758,
#        43.07070707, 43.56565657, 44.06060606, 44.55555556, 45.05050505,
#        45.54545455, 46.04040404, 46.53535354, 47.03030303, 47.52525253,
#        48.02020202, 48.51515152, 49.01010101, 49.50505051, 50.        ])

# %%
np.random.randint(50,101,size=(50,5))
# Out:
# array([[ 85,  69,  82,  74,  88],
#        [ 58,  90,  57,  80,  91],
#        [ 86,  84,  93,  77,  59],
#        [ 53,  72, 100,  75,  56],
#        [ 74,  65,  89,  58,  57],
#        [ 53,  99,  68,  93,  90],
#        [ 79,  83, 100,  90,  60],
#        [ 76,  73,  77,  80,  66],
#        [ 99,  56,  95,  55,  95],
#        [ 99,  77,  76,  95,  98],
#        [ 52,  63,  80,  78,  93],
#        [ 65,  86,  87,  59,  63],
#        [ 76,  52,  70,  88,  61],
#        [ 82,  87,  61,  56,  92],
#        [ 98,  77,  67,  95,  94],
#        [ 93,  98,  78,  69,  57],
#        [ 96,  82,  74,  70,  93],
#        [ 80,  85,  73,  67,  86],
#        [ 92,  70,  71,  75,  71],
#        [ 74,  94,  72,  78,  60],
#        [ 96,  81,  57,  93,  60],
#        [ 53,  73,  50,  90,  62],
#        [ 94,  76,  90,  71,  99],
#        [ 84,  61,  99,  69,  96],
#        [ 84,  94,  58,  58,  95],
#        [ 62,  73,  53,  60,  72],
#        [ 52,  64,  71,  81,  68],
#        [ 51,  67,  72,  81,  99],
#        [ 91,  95,  68,  55,  61],
#        [ 72,  82,  60,  83,  81],
#        [ 93,  68,  87,  59,  91],
#        [ 83,  90,  98,  50,  58],
#        [ 83,  69,  64,  73,  68],
#        [ 82,  69,  59,  91,  52],
#        [ 75,  86,  77,  92,  98],
#        [ 70,  58,  70,  90,  58],
#        [ 97,  94,  68,  61,  68],
#        [ 79,  82,  79,  73,  66],
#        [ 61,  92,  83,  72,  78],
#        [ 86,  74,  90,  63,  95],
#        [ 57,  78,  63,  82,  59],
#        [ 64,  66,  66,  73,  77],
#        [ 55,  50,  86,  89,  90],
#        [ 54,  66,  65,  95,  76],
#        [ 65,  82,  64,  96,  66],
#        [ 85,  96,  89,  88,  52],
#        [ 65,  77,  55,  81,  99],
#        [ 52,  65,  54,  93,  67],
#        [ 83,  94,  53,  50,  87],
#        [ 60,  83,  88,  58,  52]], dtype=int32)

# %%
t=np.arange(0,5,0.1)
y1=np.sin(t*np.pi)
y2=np.cos(t*np.pi)
import matplotlib.pyplot as plt
figure=plt.figure()
axes=figure.add_subplot()
axes.plot(t,y1)
axes.plot(t,y2)
a=np.linspace(1,6)
b=a*np.pi
axes.set_xticklabels(b)
plt.axes.
plt.show
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_5368\2955536798.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(b)
# <function matplotlib.pyplot.show(close=None, block=None)>
