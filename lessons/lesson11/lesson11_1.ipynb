# %%
import random
with open ("names.txt",encoding='utf-8') as file:
    contents:str = file.read()
    names:list[str] = contents.split(sep='\n')
    students_names = random.choices(names,k=50)
students_names
# Out:
# ['黃翔杰',
#  '黃佩玲',
#  '黃婷婷',
#  '劉旭士',
#  '蔡明平',
#  '黃必琪',
#  '蔡孟泉',
#  '楊健麟',
#  '王明昇',
#  '林義皓',
#  '高俊男',
#  '陳彥治',
#  '黎惠雯',
#  '陳文賢',
#  '楊韻如',
#  '童建霖',
#  '高智超',
#  '王柏聖',
#  '魏秋萍',
#  '張天亨',
#  '葉志峰',
#  '陳文賢',
#  '高士凱',
#  '盧冠發',
#  '王柏聖',
#  '白世宏',
#  '郭淑真',
#  '彭茹靖',
#  '林柏洋',
#  '劉昀天',
#  '陳逸華',
#  '林淑安',
#  '鄭淑珍',
#  '蕭怡伶',
#  '李政成',
#  '簡美君',
#  '楊又源',
#  '李進慧',
#  '黃必琪',
#  '黃旻林',
#  '黃雅慧',
#  '黃名明',
#  '陳逸凡',
#  '陳俊憲',
#  '唐雪豪',
#  '余丞苓',
#  '黃婷婷',
#  '林建宏',
#  '潘英迪',
#  '唐雪豪']

# %%
for name in students_names:
    print(name)
# Out:
# 黃翔杰
# 黃佩玲
# 黃婷婷
# 劉旭士
# 蔡明平
# 黃必琪
# 蔡孟泉
# 楊健麟
# 王明昇
# 林義皓
# 高俊男
# 陳彥治
# 黎惠雯
# 陳文賢
# 楊韻如
# 童建霖
# 高智超
# 王柏聖
# 魏秋萍
# 張天亨
# 葉志峰
# 陳文賢
# 高士凱
# 盧冠發
# 王柏聖
# 白世宏
# 郭淑真
# 彭茹靖
# 林柏洋
# 劉昀天
# 陳逸華
# 林淑安
# 鄭淑珍
# 蕭怡伶
# 李政成
# 簡美君
# 楊又源
# 李進慧
# 黃必琪
# 黃旻林
# 黃雅慧
# 黃名明
# 陳逸凡
# 陳俊憲
# 唐雪豪
# 余丞苓
# 黃婷婷
# 林建宏
# 潘英迪
# 唐雪豪

# %%
students = []
for name in students_names:
    chinese = random.randint(50,100)
    english = random.randint(50,100)
    math = random.randint(50,100)
    students.append({'姓名':name,
                    "國文":chinese,
                    "英文":english,
                    "數學":math})

students
# Out:
# [{'姓名': '黃翔杰', '國文': 59, '英文': 92, '數學': 67},
#  {'姓名': '黃佩玲', '國文': 93, '英文': 86, '數學': 81},
#  {'姓名': '黃婷婷', '國文': 92, '英文': 81, '數學': 91},
#  {'姓名': '劉旭士', '國文': 99, '英文': 72, '數學': 51},
#  {'姓名': '蔡明平', '國文': 99, '英文': 94, '數學': 69},
#  {'姓名': '黃必琪', '國文': 94, '英文': 77, '數學': 71},
#  {'姓名': '蔡孟泉', '國文': 52, '英文': 84, '數學': 82},
#  {'姓名': '楊健麟', '國文': 65, '英文': 53, '數學': 67},
#  {'姓名': '王明昇', '國文': 60, '英文': 88, '數學': 72},
#  {'姓名': '林義皓', '國文': 81, '英文': 84, '數學': 69},
#  {'姓名': '高俊男', '國文': 57, '英文': 84, '數學': 99},
#  {'姓名': '陳彥治', '國文': 52, '英文': 90, '數學': 90},
#  {'姓名': '黎惠雯', '國文': 61, '英文': 75, '數學': 84},
#  {'姓名': '陳文賢', '國文': 68, '英文': 59, '數學': 62},
#  {'姓名': '楊韻如', '國文': 85, '英文': 61, '數學': 51},
#  {'姓名': '童建霖', '國文': 54, '英文': 84, '數學': 52},
#  {'姓名': '高智超', '國文': 67, '英文': 92, '數學': 54},
#  {'姓名': '王柏聖', '國文': 54, '英文': 96, '數學': 68},
#  {'姓名': '魏秋萍', '國文': 94, '英文': 89, '數學': 68},
#  {'姓名': '張天亨', '國文': 80, '英文': 61, '數學': 97},
#  {'姓名': '葉志峰', '國文': 90, '英文': 52, '數學': 93},
#  {'姓名': '陳文賢', '國文': 61, '英文': 94, '數學': 52},
#  {'姓名': '高士凱', '國文': 68, '英文': 59, '數學': 61},
#  {'姓名': '盧冠發', '國文': 86, '英文': 80, '數學': 85},
#  {'姓名': '王柏聖', '國文': 84, '英文': 86, '數學': 62},
#  {'姓名': '白世宏', '國文': 88, '英文': 63, '數學': 76},
#  {'姓名': '郭淑真', '國文': 71, '英文': 81, '數學': 76},
#  {'姓名': '彭茹靖', '國文': 96, '英文': 98, '數學': 75},
#  {'姓名': '林柏洋', '國文': 79, '英文': 57, '數學': 73},
#  {'姓名': '劉昀天', '國文': 65, '英文': 80, '數學': 78},
#  {'姓名': '陳逸華', '國文': 94, '英文': 59, '數學': 100},
#  {'姓名': '林淑安', '國文': 99, '英文': 97, '數學': 89},
#  {'姓名': '鄭淑珍', '國文': 86, '英文': 77, '數學': 75},
#  {'姓名': '蕭怡伶', '國文': 94, '英文': 55, '數學': 54},
#  {'姓名': '李政成', '國文': 55, '英文': 73, '數學': 56},
#  {'姓名': '簡美君', '國文': 64, '英文': 80, '數學': 92},
#  {'姓名': '楊又源', '國文': 54, '英文': 77, '數學': 84},
#  {'姓名': '李進慧', '國文': 83, '英文': 68, '數學': 63},
#  {'姓名': '黃必琪', '國文': 94, '英文': 67, '數學': 91},
#  {'姓名': '黃旻林', '國文': 89, '英文': 60, '數學': 63},
#  {'姓名': '黃雅慧', '國文': 95, '英文': 67, '數學': 86},
#  {'姓名': '黃名明', '國文': 85, '英文': 64, '數學': 83},
#  {'姓名': '陳逸凡', '國文': 73, '英文': 97, '數學': 58},
#  {'姓名': '陳俊憲', '國文': 73, '英文': 84, '數學': 68},
#  {'姓名': '唐雪豪', '國文': 51, '英文': 95, '數學': 59},
#  {'姓名': '余丞苓', '國文': 59, '英文': 77, '數學': 100},
#  {'姓名': '黃婷婷', '國文': 98, '英文': 69, '數學': 83},
#  {'姓名': '林建宏', '國文': 57, '英文': 99, '數學': 85},
#  {'姓名': '潘英迪', '國文': 69, '英文': 71, '數學': 71},
#  {'姓名': '唐雪豪', '國文': 100, '英文': 65, '數學': 93}]

# %%
import os
file_path = os.path.abspath(__name__) #檔案的絕對位置
current_dir_name = os.path.dirname(file_path) #取得目前的目錄
file_position = os.path.join(current_dir_name,'data','students.csv') #操作檔案的絕對位置
file_position

import csv
with open(file_position,mode='w',newline='') as file:
    writer = csv.DictWriter(file,['姓名','國文','英文','數學'])
    writer.writeheader()
    writer.writerows(students)
