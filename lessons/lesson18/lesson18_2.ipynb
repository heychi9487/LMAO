# %%
import random
import numpy as np
import pandas as pd

with open("names.txt",encoding="utf-8") as file:
    content = file.read()

names_list = content.split()
names = random.choices(names_list,k=50)

with open("names.txt",encoding="utf-8") as file:
    content = file.read()
    
scores = np.random.randint(50,101,size=(50,5))
student_df = pd.DataFrame(scores,
             columns=['國文','英文','數學','地理','歷史'],
             index=names)
student_df
# Out:
#       國文   英文   數學  地理   歷史
# 王士銘   96   63   90  62   59
# 高士凱   94   92   63  53  100
# 鄭佳玲   83   86   55  50   58
# 林希啟   82   78   55  58   75
# 林昱芳   73   72   80  72   66
# 陳倩潔   73   74   59  90   78
# 游淑惠   80   77   74  67   95
# 錢欣潔  100   66   70  56   92
# 陳文賢   55   59   66  54   57
# 劉耿琦   90   61   96  51   85
# 張韋成   59   59   73  55   73
# 高信宏   59   53  100  94   51
# 鄭憲定   83   63   68  63   62
# 楊韋廷   88  100   57  56   95
# 李淑芳   77   91   72  75   64
# 林佳光   72   63   52  81   74
# 李佳彥   51   80   74  81   52
# 龐皓芳   70   70   99  75   73
# 白美珍   67   96   79  82   77
# 張嘉韋   65   97   86  97   98
# 鍾俞禎   53   92   82  66   56
# 蔡偉成   64   98   50  95   77
# 鄭佳玲   90   56   97  67   96
# 陳冠竹   84   83   61  57   50
# 賴苑禾   89   74   61  75   96
# 陳倩妮   67   89   72  79   55
# 劉昀天   71   68   56  62   71
# 林志喜   85   64   73  59   80
# 謝水儒   99   70   85  84   84
# 王柏聖   61   80   65  95   50
# 楊韻如   64   80   93  89   53
# 藍姿婷   86   66   65  73   53
# 陳淑娟   66   63   88  96   88
# 王怡珊   80   52   80  75   91
# 林珍旺   98   68   71  97   60
# 陳孝邦   50   99   70  89   75
# 謝佳穎   64  100   96  69   54
# 昌嘉洋   92   80   82  72   58
# 黃必琪   76   89   96  78   61
# 蘇婷婷   50   61   96  88   86
# 趙家豪   53   83   52  72   91
# 余月修   94   59   78  64   72
# 張天亨   86   52   88  97   54
# 游淑惠   96   50   80  73   95
# 游淑惠  100   82   96  62   97
# 林希啟   72   64   83  73   63
# 陳信宏   97   72   61  60   55
# 柯宜臻   85   93   86  67   68
# 林玉佩   57   66   86  78   61
# 黃志福   79   99   96  61   51

# %%
from pandas import Series,DataFrame
def fun3(s:Series):
    sum = s.sum()
    mean = s.mean()
    count = s[s<60].count()
    values = s[s<60].index.values
    return Series([sum,mean,count,values],index=['總分','平均','不及格數','不及格科目'])

student_df.apply(fun3,axis=1)
# Out:
#       總分    平均  不及格數             不及格科目
# 王士銘  370  74.0     1              [歷史]
# 高士凱  402  80.4     1              [地理]
# 鄭佳玲  332  66.4     3      [數學, 地理, 歷史]
# 林希啟  348  69.6     2          [數學, 地理]
# 林昱芳  363  72.6     0                []
# 陳倩潔  374  74.8     1              [數學]
# 游淑惠  393  78.6     0                []
# 錢欣潔  384  76.8     1              [地理]
# 陳文賢  291  58.2     4  [國文, 英文, 地理, 歷史]
# 劉耿琦  383  76.6     1              [地理]
# 張韋成  319  63.8     3      [國文, 英文, 地理]
# 高信宏  357  71.4     3      [國文, 英文, 歷史]
# 鄭憲定  339  67.8     0                []
# 楊韋廷  396  79.2     2          [數學, 地理]
# 李淑芳  379  75.8     0                []
# 林佳光  342  68.4     1              [數學]
# 李佳彥  338  67.6     2          [國文, 歷史]
# 龐皓芳  387  77.4     0                []
# 白美珍  401  80.2     0                []
# 張嘉韋  443  88.6     0                []
# 鍾俞禎  349  69.8     2          [國文, 歷史]
# 蔡偉成  384  76.8     1              [數學]
# 鄭佳玲  406  81.2     1              [英文]
# 陳冠竹  335  67.0     2          [地理, 歷史]
# 賴苑禾  395  79.0     0                []
# 陳倩妮  362  72.4     1              [歷史]
# 劉昀天  328  65.6     1              [數學]
# 林志喜  361  72.2     1              [地理]
# 謝水儒  422  84.4     0                []
# 王柏聖  351  70.2     1              [歷史]
# 楊韻如  379  75.8     1              [歷史]
# 藍姿婷  343  68.6     1              [歷史]
# 陳淑娟  401  80.2     0                []
# 王怡珊  378  75.6     1              [英文]
# 林珍旺  394  78.8     0                []
# 陳孝邦  383  76.6     1              [國文]
# 謝佳穎  383  76.6     1              [歷史]
# 昌嘉洋  384  76.8     1              [歷史]
# 黃必琪  400  80.0     0                []
# 蘇婷婷  381  76.2     1              [國文]
# 趙家豪  351  70.2     2          [國文, 數學]
# 余月修  367  73.4     1              [英文]
# 張天亨  377  75.4     2          [英文, 歷史]
# 游淑惠  394  78.8     1              [英文]
# 游淑惠  437  87.4     0                []
# 林希啟  355  71.0     0                []
# 陳信宏  345  69.0     1              [歷史]
# 柯宜臻  399  79.8     0                []
# 林玉佩  348  69.6     1              [國文]
# 黃志福  386  77.2     1              [歷史]
