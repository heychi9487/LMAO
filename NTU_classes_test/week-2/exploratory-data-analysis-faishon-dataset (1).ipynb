# %%
# for data cleaning and processing
import numpy as np
import pandas as pd

# for drawing
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# for ignoring warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('FashionDataset.csv')
data.head()
# Out:
#    Unnamed: 0    BrandName                                            Deatils  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
data.shape
# Out:
# (30758, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30758 non-null  int64
#  1   BrandName   30758 non-null  object
#  2   Deatils     30758 non-null  object
#  3   Sizes       30758 non-null  object
#  4   MRP         30758 non-null  object
#  5   SellPrice   30758 non-null  object
#  6   Discount    30758 non-null  object
#  7   Category    30758 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Data cleaning and process

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'BrandName', 'Deatils', 'Sizes', 'MRP', 'SellPrice',
#        'Discount', 'Category'],
#       dtype='object')

# %% [markdown]
# ### Let's see what all we can explore in this dataset
# 1. Which brand is most costly / affordable to the customer?
#
# 2. Which category has maximum options in women wear
#
# 3. How much Discount does each brand gives to it's customers?
#
# 4. How many option in sizes do women have?

# %%
data.rename(columns={'Deatils':'Details'})
# Out:
#        Unnamed: 0    BrandName  \
# 0               0         life
# 1               1         only
# 2               2      fratini
# 3               3  zink london
# 4               4         life
# ...           ...          ...
# 30753          21    swarovski
# 30754          22          Nan
# 30755          23       jewelz
# 30756          24      estelle
# 30757          25      estelle
#
#                                                  Details  \
# 0      solid cotton blend collar neck womens a-line d...
# 1      polyester peter pan collar womens blouson dres...
# 2      solid polyester blend wide neck womens regular...
# 3      stripes polyester sweetheart neck womens dress...
# 4      regular fit regular length denim womens jeans ...
# ...                                                  ...
# 30753            crystal stylish womens rodhium earrings
# 30754                                                Nan
# 30755                 ethnic gold plated jhumki earrings
# 30756  womens gold plated double line fancy white and...
# 30757  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30753                                      Nan       Nan      8950      Nan
# 30754                                      Nan       Nan       Nan      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30753    Jewellery-Women
# 30754    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [30758 rows x 8 columns]

# %%
data.isna().any()
# Out:
# Unnamed: 0    False
# BrandName     False
# Deatils       False
# Sizes         False
# MRP           False
# SellPrice     False
# Discount      False
# Category      False
# dtype: bool

# %%
data.isna()
# Out:
#        Unnamed: 0  BrandName  Deatils  Sizes    MRP  SellPrice  Discount  \
# 0           False      False    False  False  False      False     False
# 1           False      False    False  False  False      False     False
# 2           False      False    False  False  False      False     False
# 3           False      False    False  False  False      False     False
# 4           False      False    False  False  False      False     False
# ...           ...        ...      ...    ...    ...        ...       ...
# 30753       False      False    False  False  False      False     False
# 30754       False      False    False  False  False      False     False
# 30755       False      False    False  False  False      False     False
# 30756       False      False    False  False  False      False     False
# 30757       False      False    False  False  False      False     False
#
#        Category
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 30753     False
# 30754     False
# 30755     False
# 30756     False
# 30757     False
#
# [30758 rows x 8 columns]

# %% [markdown]
# ### There is no null values in dataset

# %% [markdown]
# ### Before we move further, Let's drop or replace few features that we feel won't contribute much to our analysis - such as
# Unnamed column
#
# 'Rs\n' from the MRP column
#
# 'Size:' from Sizes column
#
# Converting all prices into integer type.

# %%
df=data.copy()

# %%
df.head()
# Out:
#    Unnamed: 0    BrandName                                            Deatils  \
# 0           0         life  solid cotton blend collar neck womens a-line d...
# 1           1         only  polyester peter pan collar womens blouson dres...
# 2           2      fratini  solid polyester blend wide neck womens regular...
# 3           3  zink london  stripes polyester sweetheart neck womens dress...
# 4           4         life  regular fit regular length denim womens jeans ...
#
#                                      Sizes       MRP SellPrice Discount  \
# 0  Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                         Size:34,36,38,40  Rs\n3499      2449  30% off
# 2              Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3          Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                   Size:26,28,30,32,34,36  Rs\n1699       849  50% off
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %%
df.Sizes.unique()
# Out:
# array(['Size:Large,Medium,Small,X-Large,X-Small', 'Size:34,36,38,40',
#        'Size:Large,X-Large,XX-Large', ..., 'Size:3,8', 'Size:36,41',
#        'Size:4,4.5,8.5'], dtype=object)

# %%
df.drop('Unnamed: 0', axis=1, inplace = True)
df
# Out:
#          BrandName                                            Deatils  \
# 0             life  solid cotton blend collar neck womens a-line d...
# 1             only  polyester peter pan collar womens blouson dres...
# 2          fratini  solid polyester blend wide neck womens regular...
# 3      zink london  stripes polyester sweetheart neck womens dress...
# 4             life  regular fit regular length denim womens jeans ...
# ...            ...                                                ...
# 30753    swarovski            crystal stylish womens rodhium earrings
# 30754          Nan                                                Nan
# 30755       jewelz                 ethnic gold plated jhumki earrings
# 30756      estelle  womens gold plated double line fancy white and...
# 30757      estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30753                                      Nan       Nan      8950      Nan
# 30754                                      Nan       Nan       Nan      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30753    Jewellery-Women
# 30754    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [30758 rows x 7 columns]

# %%
df.replace('Nan', np.nan, inplace = True)
df
# Out:
#          BrandName                                            Deatils  \
# 0             life  solid cotton blend collar neck womens a-line d...
# 1             only  polyester peter pan collar womens blouson dres...
# 2          fratini  solid polyester blend wide neck womens regular...
# 3      zink london  stripes polyester sweetheart neck womens dress...
# 4             life  regular fit regular length denim womens jeans ...
# ...            ...                                                ...
# 30753    swarovski            crystal stylish womens rodhium earrings
# 30754          NaN                                                NaN
# 30755       jewelz                 ethnic gold plated jhumki earrings
# 30756      estelle  womens gold plated double line fancy white and...
# 30757      estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30753                                      NaN       NaN      8950      NaN
# 30754                                      NaN       NaN       NaN      NaN
# 30755                                      NaN  Rs\n1839       643  65% off
# 30756                                      NaN       NaN      2799      NaN
# 30757                                      NaN       NaN      1899      NaN
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30753    Jewellery-Women
# 30754    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [30758 rows x 7 columns]

# %%
df.dropna(axis=0, inplace=True)
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                          Sizes        MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small   Rs\n1699       849  50% off
# 1                             Size:34,36,38,40   Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large   Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large   Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36   Rs\n1699       849  50% off
# ...                                        ...        ...       ...      ...
# 26673                      Size:36,37,38,39,40   Rs\n2999      1499  50% off
# 26674                      Size:36,37,38,39,40   Rs\n2199      1099  50% off
# 26885                          Size:Error Size  Rs\n13990      4197  70% off
# 27290                          Size:Error Size   Rs\n7499      4999  33% off
# 28418                          Size:Error Size   Rs\n5999      3999  33% off
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df['Sizes']=df['Sizes'].str.replace('Size:',' ')
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes        MRP SellPrice Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   Rs\n1699       849  50% off
# 1                              34,36,38,40   Rs\n3499      2449  30% off
# 2                   Large,X-Large,XX-Large   Rs\n1199       599  50% off
# 3               Large,Medium,Small,X-Large   Rs\n2299      1379  40% off
# 4                        26,28,30,32,34,36   Rs\n1699       849  50% off
# ...                                    ...        ...       ...      ...
# 26673                       36,37,38,39,40   Rs\n2999      1499  50% off
# 26674                       36,37,38,39,40   Rs\n2199      1099  50% off
# 26885                           Error Size  Rs\n13990      4197  70% off
# 27290                           Error Size   Rs\n7499      4999  33% off
# 28418                           Error Size   Rs\n5999      3999  33% off
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df['Discount']=df['Discount'].str.replace('% off','')
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes        MRP SellPrice Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   Rs\n1699       849       50
# 1                              34,36,38,40   Rs\n3499      2449       30
# 2                   Large,X-Large,XX-Large   Rs\n1199       599       50
# 3               Large,Medium,Small,X-Large   Rs\n2299      1379       40
# 4                        26,28,30,32,34,36   Rs\n1699       849       50
# ...                                    ...        ...       ...      ...
# 26673                       36,37,38,39,40   Rs\n2999      1499       50
# 26674                       36,37,38,39,40   Rs\n2199      1099       50
# 26885                           Error Size  Rs\n13990      4197       70
# 27290                           Error Size   Rs\n7499      4999       33
# 28418                           Error Size   Rs\n5999      3999       33
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df['MRP']=df['MRP'].str.replace('Rs\n','')
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes    MRP SellPrice Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   1699       849       50
# 1                              34,36,38,40   3499      2449       30
# 2                   Large,X-Large,XX-Large   1199       599       50
# 3               Large,Medium,Small,X-Large   2299      1379       40
# 4                        26,28,30,32,34,36   1699       849       50
# ...                                    ...    ...       ...      ...
# 26673                       36,37,38,39,40   2999      1499       50
# 26674                       36,37,38,39,40   2199      1099       50
# 26885                           Error Size  13990      4197       70
# 27290                           Error Size   7499      4999       33
# 28418                           Error Size   5999      3999       33
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df['SellPrice']=df['SellPrice'].astype(int)
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes    MRP  SellPrice Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   1699        849       50
# 1                              34,36,38,40   3499       2449       30
# 2                   Large,X-Large,XX-Large   1199        599       50
# 3               Large,Medium,Small,X-Large   2299       1379       40
# 4                        26,28,30,32,34,36   1699        849       50
# ...                                    ...    ...        ...      ...
# 26673                       36,37,38,39,40   2999       1499       50
# 26674                       36,37,38,39,40   2199       1099       50
# 26885                           Error Size  13990       4197       70
# 27290                           Error Size   7499       4999       33
# 28418                           Error Size   5999       3999       33
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df['Discount']=df['Discount'].astype(int)
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes    MRP  SellPrice  Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   1699        849        50
# 1                              34,36,38,40   3499       2449        30
# 2                   Large,X-Large,XX-Large   1199        599        50
# 3               Large,Medium,Small,X-Large   2299       1379        40
# 4                        26,28,30,32,34,36   1699        849        50
# ...                                    ...    ...        ...       ...
# 26673                       36,37,38,39,40   2999       1499        50
# 26674                       36,37,38,39,40   2199       1099        50
# 26885                           Error Size  13990       4197        70
# 27290                           Error Size   7499       4999        33
# 28418                           Error Size   5999       3999        33
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [18374 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18374 entries, 0 to 28418
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BrandName  18374 non-null  object
#  1   Deatils    18374 non-null  object
#  2   Sizes      18374 non-null  object
#  3   MRP        18374 non-null  object
#  4   SellPrice  18374 non-null  int32
#  5   Discount   18374 non-null  int32
#  6   Category   18374 non-null  object
# dtypes: int32(2), object(5)
# memory usage: 1004.8+ KB

# %%
df.head()
# Out:
#      BrandName                                            Deatils  \
# 0         life  solid cotton blend collar neck womens a-line d...
# 1         only  polyester peter pan collar womens blouson dres...
# 2      fratini  solid polyester blend wide neck womens regular...
# 3  zink london  stripes polyester sweetheart neck womens dress...
# 4         life  regular fit regular length denim womens jeans ...
#
#                                  Sizes   MRP  SellPrice  Discount  \
# 0   Large,Medium,Small,X-Large,X-Small  1699        849        50
# 1                          34,36,38,40  3499       2449        30
# 2               Large,X-Large,XX-Large  1199        599        50
# 3           Large,Medium,Small,X-Large  2299       1379        40
# 4                    26,28,30,32,34,36  1699        849        50
#
#             Category
# 0  Westernwear-Women
# 1  Westernwear-Women
# 2  Westernwear-Women
# 3  Westernwear-Women
# 4  Westernwear-Women

# %% [markdown]
# ###  brand  most costly / affordable to the customer?

# %%
df.loc[df.duplicated()]
# Out:
#        BrandName                                            Deatils  \
# 24          life  regular fit regular length denim womens jeans ...
# 148         life  printed cotton lycra round neck womens t-shirt...
# 280         life  printed cotton lycra round neck womens t-shirt...
# 356         life  skinny fit regular length cotton lycra womens ...
# 533         life  embroidered cotton blend round neck womens top...
# ...          ...                                                ...
# 26391  shoetopia             synthetic womens casual sandals - gold
# 26405    catwalk  polyurethane slipon womens casual loafers - brown
# 26513     modare  pu slip on round toe womens casual flip flops ...
# 26518     modare              pu zipper womens casual boots - black
# 26538  shoetopia              synthetic womens casual slides - pink
#
#                                      Sizes   MRP  SellPrice  Discount  \
# 24                       26,28,30,32,34,36  1999        999        50
# 148     Large,Medium,Small,X-Large,X-Small   699        349        50
# 280     Large,Medium,Small,X-Large,X-Small   699        349        50
# 356                      26,28,30,32,34,36   999        499        50
# 533     Large,Medium,Small,X-Large,X-Small  1299        649        50
# ...                                    ...   ...        ...       ...
# 26391                       37,38,39,40,41   999        699        30
# 26405                                5,6,7  2895       1447        50
# 26513                       36,37,38,39,40  3499       2449        30
# 26518                       36,37,38,39,40  6999       4899        30
# 26538                             36,37,38   999        499        50
#
#                 Category
# 24     Westernwear-Women
# 148    Westernwear-Women
# 280    Westernwear-Women
# 356    Westernwear-Women
# 533    Westernwear-Women
# ...                  ...
# 26391     Footwear-Women
# 26405     Footwear-Women
# 26513     Footwear-Women
# 26518     Footwear-Women
# 26538     Footwear-Women
#
# [443 rows x 7 columns]

# %%
df.shape
# Out:
# (18374, 7)

# %%
df.loc[df.duplicated()]
# Out:
#        BrandName                                            Deatils  \
# 24          life  regular fit regular length denim womens jeans ...
# 148         life  printed cotton lycra round neck womens t-shirt...
# 280         life  printed cotton lycra round neck womens t-shirt...
# 356         life  skinny fit regular length cotton lycra womens ...
# 533         life  embroidered cotton blend round neck womens top...
# ...          ...                                                ...
# 26391  shoetopia             synthetic womens casual sandals - gold
# 26405    catwalk  polyurethane slipon womens casual loafers - brown
# 26513     modare  pu slip on round toe womens casual flip flops ...
# 26518     modare              pu zipper womens casual boots - black
# 26538  shoetopia              synthetic womens casual slides - pink
#
#                                      Sizes   MRP  SellPrice  Discount  \
# 24                       26,28,30,32,34,36  1999        999        50
# 148     Large,Medium,Small,X-Large,X-Small   699        349        50
# 280     Large,Medium,Small,X-Large,X-Small   699        349        50
# 356                      26,28,30,32,34,36   999        499        50
# 533     Large,Medium,Small,X-Large,X-Small  1299        649        50
# ...                                    ...   ...        ...       ...
# 26391                       37,38,39,40,41   999        699        30
# 26405                                5,6,7  2895       1447        50
# 26513                       36,37,38,39,40  3499       2449        30
# 26518                       36,37,38,39,40  6999       4899        30
# 26538                             36,37,38   999        499        50
#
#                 Category
# 24     Westernwear-Women
# 148    Westernwear-Women
# 280    Westernwear-Women
# 356    Westernwear-Women
# 533    Westernwear-Women
# ...                  ...
# 26391     Footwear-Women
# 26405     Footwear-Women
# 26513     Footwear-Women
# 26518     Footwear-Women
# 26538     Footwear-Women
#
# [443 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#             BrandName                                            Deatils  \
# 0                life  solid cotton blend collar neck womens a-line d...
# 1                only  polyester peter pan collar womens blouson dres...
# 2             fratini  solid polyester blend wide neck womens regular...
# 3         zink london  stripes polyester sweetheart neck womens dress...
# 4                life  regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26673  lemon & pepper     womens casual wear buckle closure flats - navy
# 26674     haute curry           womens casual wear slip on heels - black
# 26885     swiss eagle                     womens analogue metallic watch
# 27290  lawman watches  womens rose gold dial stainless steel analogue...
# 28418  lawman watches  womens silver dial stainless steel analogue wa...
#
#                                      Sizes    MRP  SellPrice  Discount  \
# 0       Large,Medium,Small,X-Large,X-Small   1699        849        50
# 1                              34,36,38,40   3499       2449        30
# 2                   Large,X-Large,XX-Large   1199        599        50
# 3               Large,Medium,Small,X-Large   2299       1379        40
# 4                        26,28,30,32,34,36   1699        849        50
# ...                                    ...    ...        ...       ...
# 26673                       36,37,38,39,40   2999       1499        50
# 26674                       36,37,38,39,40   2199       1099        50
# 26885                           Error Size  13990       4197        70
# 27290                           Error Size   7499       4999        33
# 28418                           Error Size   5999       3999        33
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 26673     Footwear-Women
# 26674     Footwear-Women
# 26885      Watches-Women
# 27290      Watches-Women
# 28418      Watches-Women
#
# [17931 rows x 7 columns]

# %%
df.shape
# Out:
# (17931, 7)

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [BrandName, Deatils, Sizes, MRP, SellPrice, Discount, Category]
# Index: []

# %% [markdown]
# #### All duplicates are removed

# %% [markdown]
# ## visualization

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Price Distribution Plot')
sns.distplot(df.SellPrice)

plt.subplot(1,2,2)
plt.title('Price Spread')
sns.boxplot(y=df.SellPrice)

plt.show()

# %%
prices = df['SellPrice'].value_counts()
plt.figure(figsize=(15,5))

plt.grid()
plt.plot(prices, '.', alpha=0.6, markersize=10)
plt.title('Selling prices')
plt.show()

# %%
df.SellPrice.describe(percentiles=[0.25,0.50,0.75,0.85,0.95])
# Out:
# count    17931.000000
# mean      1171.061792
# std        746.728662
# min        114.000000
# 25%        667.000000
# 50%        999.000000
# 75%       1484.000000
# 85%       1799.000000
# 95%       2569.500000
# max      13599.000000
# Name: SellPrice, dtype: float64

# %% [markdown]
# ### Inferences:
# 1. the plot seems to slightly right-skewed meaning the most price in dataset are high
# 2. there is significant differnce between mean and median
# 3. 95% of the selling price is less than rs 2570
# 4. data points are slightly spread out from mean which indicates low variance in the price(85% of price are below
#    1799) whereas the remaning 15% are  between 1799 and 13599

# %% [markdown]
# ### Brand that is costly / affordable to the customer

# %% [markdown]
# ## most costly

# %%
max_price = df['SellPrice'].max()
brand=df.loc[ max_price == df['SellPrice'],'BrandName'].iloc[0]
categ=df.loc[max_price ==df['SellPrice'],'Category'].iloc[0]
print(brand ,'is most costly among all the Brands with category ',categ ,'at Rs' ,max_price)
# Out:
# global desi is most costly among all the Brands with category  Indianwear-Women at Rs 13599

# %%
A = df.groupby(['BrandName','Category'])['SellPrice']
A

# %%
B = A.max()
B
# Out:
# BrandName    Category
# 109f         Westernwear-Women           1399
# aarke        Indianwear-Women            1140
# adidas       Lingerie&Nightwear-Women    2519
#              Westernwear-Women           3499
# allen solly  Westernwear-Women           3599
#                                          ...
# yuris        Westernwear-Women            949
# zink london  Indianwear-Women            1519
#              Westernwear-Women           2399
# ziyaa        Indianwear-Women            2550
#              Lingerie&Nightwear-Women    1503
# Name: SellPrice, Length: 156, dtype: int32

# %%
C = B.reset_index()
C
# Out:
#        BrandName                  Category  SellPrice
# 0           109f         Westernwear-Women       1399
# 1          aarke          Indianwear-Women       1140
# 2         adidas  Lingerie&Nightwear-Women       2519
# 3         adidas         Westernwear-Women       3499
# 4    allen solly         Westernwear-Women       3599
# ..           ...                       ...        ...
# 151        yuris         Westernwear-Women        949
# 152  zink london          Indianwear-Women       1519
# 153  zink london         Westernwear-Women       2399
# 154        ziyaa          Indianwear-Women       2550
# 155        ziyaa  Lingerie&Nightwear-Women       1503
#
# [156 rows x 3 columns]

# %%
#max_price=df.groupby(['BrandName','Category'])['SellPrice'].max().reset_index().sort_values(by='SellPrice',ascending=False).head(10)
#max_price=df.groupby(['BrandName','Category'])['SellPrice'].max().sort_values(by='SellPrice',ascending=False).head(10)

max_price=df.groupby(['BrandName','Category'], as_index=False)['SellPrice'].max().sort_values(by='SellPrice',ascending=False).head(10)

max_price
# Out:
#           BrandName           Category  SellPrice
# 44      global desi   Indianwear-Women      13599
# 146               w   Indianwear-Women       7499
# 102     new balance     Footwear-Women       6999
# 46            guess     Footwear-Women       6299
# 18           clarks     Footwear-Women       6299
# 37      forever new  Westernwear-Women       6000
# 12             biba   Indianwear-Women       5596
# 94           myshka   Indianwear-Women       5399
# 68          juniper   Indianwear-Women       5157
# 77   lawman watches      Watches-Women       4999

# %%
max_price = df['SellPrice'].max()
print(max_price)

# %%
max_price == df['SellPrice']

# %%
df.loc[ max_price == df['SellPrice'],'BrandName']

# %%
df.loc[ max_price == df['SellPrice'],'BrandName'].iloc[0]

# %%
df.loc[ max_price == df['SellPrice']]

# %%
max_price=df.groupby(['BrandName','Category'])['SellPrice'].max().reset_index().sort_values(by='SellPrice',ascending=False).head(10)
plt.figure(figsize=(25,8))

plt.subplot(1,2,1)
plt.title('Top 10 costly Brand')
sns.barplot(x='BrandName' , y='SellPrice' ,data=max_price)

plt.subplot(1,2,2)
plt.title('Top costly Category')
sns.barplot(x='Category' , y='SellPrice' ,data=max_price)


plt.show()

# %% [markdown]
# ### Inferences :
# 1. Most Costier Brand is global desi
# 2. Most costier Category is Indianwear

# %%
min_price=df.groupby(['BrandName','Category'])['SellPrice'].min().reset_index().sort_values(by='SellPrice',ascending=True).head(10)
min_price

# %%
plt.figure(figsize=(25,8))

plt.subplot(1,2,1)
plt.title('Top 10 cheap Brand')
sns.barplot(x='BrandName' , y='SellPrice' ,data=min_price)

plt.subplot(1,2,2)
plt.title('Top cheap Category')
sns.barplot(x='Category' , y='SellPrice' ,data=min_price)


plt.show()

# %% [markdown]
# ### Inferences :
# 1. Most cheapest Brand is clovia
# 2. Most cheapest Category is Lingeries

# %%
plt.figure(figsize=(15,6))
yearly_opening_rank = df.groupby(['SellPrice','BrandName']).BrandName.count().head(20).plot(kind = 'bar', color ='#1a55FF')
plt.show()

# %% [markdown]
# ### Inferences :
# The above plots gives us an estimated range of clothes i.e between Rs 500 to 2500. While the plot in Yellow has slight lower range ofvalues certainly due to brands having Lingerie type of women wear.

# %%
optional_clothing=df.groupby(['Category']).count().reset_index()

plt.figure(figsize=(25,6))

plt.subplot(1,2,1)
sns.barplot(x='Category' , y='BrandName' ,data=optional_clothing)

optional_clothing=df['Category'].value_counts()

plt.subplot(1,2,2)
plt.plot(optional_clothing,'.', alpha=0.6, markersize=50)
plt.plot(optional_clothing)
plt.show()

# %% [markdown]
# ### Inferences :
#  Westernwear has maximum options for women wear

# %%
plt.figure(figsize=(25,5))

plt.subplot(1,2,1)
plt.title('BrandName and Discount')
df.groupby(['BrandName'])['Discount'].value_counts().plot()

plt.subplot(1,2,2)
plt.title('Maxium count of discount')
df['Discount'].value_counts().head(100).plot(kind='bar')
plt.show()

# %% [markdown]
# ### Inferences:
# From the above plot, we can say that Most brands tuning it in about max of 50% to min of 10%.

# %%
plt.figure(figsize=(25,6))
plt.title('Maxium Discount on Category')
Dis=df.groupby(['Category'])['Discount'].max()
plt.grid(color='black',linewidth = 0.25)
plt.plot(Dis,'.', alpha=0.6, markersize=50,marker='o')
plt.plot(Dis,color='red',marker='+')
plt.show()

# %% [markdown]
# ### Inferences:
# From the above plot, we can say that maximum Discount is given on IndianWear

# %%
df.columns

# %%
plt.figure(figsize=(25,5))

plt.subplot(1,2,1)
plt.title('BrandName and Sizes')
df.groupby(['BrandName','Sizes']).Sizes.count().sort_values(ascending=False).head(10).plot(kind='bar',color='#bcbd22')

plt.subplot(1,2,2)
plt.title('Sizes Count')
df['Sizes'].value_counts().head(10).plot(kind='bar',color='#e377c2')
plt.legend()

# %% [markdown]
# #### As fashion industry is progressing, the brands are trying their best to fit into every customer size from small to XL sizes as well. Thus, from the above analysis it is clear that though the gap is shortneing but their is still high demand for sizes in Small,X-Small, Medium, Large and X-Large
